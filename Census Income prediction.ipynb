# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
census=pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv')
census
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
# Checking the shape of the dataset-

print("Number of rows in the dataset: ",census.shape[0])
print("Number of columns in the dataset: ",census.shape[1])
# Out:
# Number of rows in the dataset:  32560
# Number of columns in the dataset:  15

# %%
census.columns.to_list()
# Out:
# ['Age',
#  'Workclass',
#  'Fnlwgt',
#  'Education',
#  'Education_num',
#  'Marital_status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Capital_gain',
#  'Capital_loss',
#  'Hours_per_week',
#  'Native_country',
#  'Income']

# %%
census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# There is object and integer data type present in the dataset. There are no null values in dataset.

# %%
numerical_cols=[]
for i in census.dtypes.index:
    if census.dtypes[i]=='int64':
        numerical_cols.append(i)
    
categorical_cols=[]
for i in census.dtypes.index:
    if census.dtypes[i]=='object':
        categorical_cols.append(i)

print('Numerical column: ',numerical_cols,'\n')
print('Categorical column: ',categorical_cols)
# Out:
# Numerical column:  ['Age', 'Fnlwgt', 'Education_num', 'Capital_gain', 'Capital_loss', 'Hours_per_week']
#
# Categorical column:  ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']

# %%
census.nunique()
# Out:
# Age                  73
# Workclass             9
# Fnlwgt            21647
# Education            16
# Education_num        16
# Marital_status        7
# Occupation           15
# Relationship          6
# Race                  5
# Sex                   2
# Capital_gain        119
# Capital_loss         92
# Hours_per_week       94
# Native_country       42
# Income                2
# dtype: int64

# %%
for i in census.columns:
    if census[i].dtypes =='object':
        print(i,'\n',census[i].value_counts())
        print('=='*50)
# Out:
# Workclass
#   Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
# ====================================================================================================
# Education
#   HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64
# ====================================================================================================
# Marital_status
#   Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64
# ====================================================================================================
# Occupation
#   Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64
# ====================================================================================================
# Relationship
#   Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64
# ====================================================================================================
# Race
#   White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64
# ====================================================================================================
# Sex
#   Male      21789
#  Female    10771
# Name: Sex, dtype: int64
# ====================================================================================================
# Native_country
#   United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: Native_country, dtype: int64
# ====================================================================================================
# Income
#   <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64
# ====================================================================================================

# %%
#replacing ? with mode values
mode_col = ['Workclass','Occupation','Native_country']
for i in mode_col:
    census[i].replace("?",census[i].mode()[0],inplace = True)

# %%
census.sample(10)
# Out:
#        Age          Workclass  Fnlwgt      Education  Education_num  \
# 12880   17            Private   96282           10th              6
# 2247    20            Private  236769   Some-college             10
# 24736   67            Private  336163        HS-grad              9
# 11618   51            Private  177727     Assoc-acdm             12
# 22771   35            Private   90406           11th              7
# 17552   30            Private  203488   Some-college             10
# 21469   55   Self-emp-not-inc   68006        7th-8th              4
# 25098   22                  ?   61499        HS-grad              9
# 17677   46          Local-gov  175754        Masters             14
# 9024    27            Private  161683           11th              7
#
#             Marital_status          Occupation     Relationship    Race  \
# 12880        Never-married       Other-service        Own-child   White
# 2247         Never-married   Handlers-cleaners        Own-child   White
# 24736   Married-civ-spouse   Handlers-cleaners          Husband   White
# 11618   Married-civ-spouse        Craft-repair          Husband   White
# 22771   Married-civ-spouse               Sales             Wife   White
# 17552        Never-married        Craft-repair    Not-in-family   White
# 21469        Never-married       Other-service   Other-relative   White
# 25098        Never-married                   ?    Not-in-family   White
# 17677             Divorced      Prof-specialty    Not-in-family   White
# 9024    Married-civ-spouse   Machine-op-inspct          Husband   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 12880     Male             0             0              14   United-States
# 2247      Male             0             0              40   United-States
# 24736     Male             0             0              24   United-States
# 11618     Male             0             0              45   United-States
# 22771   Female             0             0              40   United-States
# 17552     Male             0             0              44   United-States
# 21469   Female             0             0              60   United-States
# 25098   Female             0             0              40   United-States
# 17677   Female             0          1876              60   United-States
# 9024      Male             0             0              42   United-States
#
#        Income
# 12880   <=50K
# 2247    <=50K
# 24736   <=50K
# 11618    >50K
# 22771   <=50K
# 17552   <=50K
# 21469   <=50K
# 25098   <=50K
# 17677   <=50K
# 9024    <=50K

# %%
plt.figure(figsize=[10,8])
sns.heatmap(census.isnull())
print(census.isnull().sum())
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
census.duplicated().sum()
# Out:
# 24

# %% [markdown]
# There are 24 duplicate values.

# %%
#Deleting duplicate data in the given dataset
census.drop_duplicates(inplace=True)
census.shape
# Out:
# (32536, 15)

# %%
census.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32536.000000  3.253600e+04   32536.000000  32536.000000  32536.000000
# mean      38.585536  1.897843e+05      10.081725   1078.410069     87.370912
# std       13.638193  1.055563e+05       2.571622   7388.068465    403.107737
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369932e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32536.000000
# mean        40.440343
# std         12.347079
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# The mean is greater than median in all the columns , which indicates that the data is right sided skewed .
# 75% of the population is below 48 years of age.
# The difference between 75% and max values is also very large, which shows presence of outliers in our dataset.
# Many zero values in the capital_gain and capital_loss column. It might suggests abnormality in both the columns
# The Minimum age is 17 and maximum age is 90.
# The average working hours per week is 40 hours.

# %%
# checking zero count 
zero_col = ['Capital_loss','Capital_gain']
for i in zero_col:
    print(census[census[i]==0].count(),'\n')
# Out:
# Age               31017
# Workclass         31017
# Fnlwgt            31017
# Education         31017
# Education_num     31017
# Marital_status    31017
# Occupation        31017
# Relationship      31017
# Race              31017
# Sex               31017
# Capital_gain      31017
# Capital_loss      31017
# Hours_per_week    31017
# Native_country    31017
# Income            31017
# dtype: int64
#
# Age               29825
# Workclass         29825
# Fnlwgt            29825
# Education         29825
# Education_num     29825
# Marital_status    29825
# Occupation        29825
# Relationship      29825
# Race              29825
# Sex               29825
# Capital_gain      29825
# Capital_loss      29825
# Hours_per_week    29825
# Native_country    29825
# Income            29825
# dtype: int64

# %% [markdown]
# Data Visualisation

# %%
for i in categorical_cols:
    plt.figure(figsize=(8,3))
    sns.histplot(x=census[i],palette='Blues',multiple="stack",hue=census['Income'])
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in categorical_cols:
    plt.figure(figsize=(15,6))
    census[i].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
    plt.xlabel(i)
    plt.ylabel('')
    plt.show()

# %% [markdown]
# More than 69.7 % of the population works in a Private company than any other local or government organizations.
# More than 46% of the population are married and 32% never married.
# The count of individuals working as a Prof-specialty> Craft-repair > Exec-managerial > Adm-clerical > Sales > Other-service.
# The count of individuals as husband> not-in-family.
# More than 85% of population are white in color and only approx 10% are black colored.
# 67% are male population and 33% are female population.
# More than 90% working professionals are US citizens.
# Almost 76% have income less than $50k per year.Hence target variable is imbalanced
# Most of the population has completed high school graduation > some community-college>bachelor people.

# %%
plt.figure(figsize = [25,15])
sns.countplot(x=census.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in census.columns:
    if census[i].dtypes == "object":
        census[i] = le.fit_transform(census[i].values.reshape(-1,1))
census.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1             0             0
# 1           6             1     4    1             0             0
# 2           6             0     2    1             0             0
# 3          10             5     2    0             0             0
# 4           4             5     4    0             0             0
#
#    Hours_per_week  Native_country  Income
# 0              13              39       0
# 1              40              39       0
# 2              40              39       0
# 3              40               5       0
# 4              40              39       0

# %%
#Plotting the correlation of columns
plt.figure(figsize=[12,10])
sns.heatmap(census.corr(),annot = True, fmt = '0.2f',cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
print(census.corr()['Income'].drop('Income').sort_values(ascending = False))
plt.figure(figsize = [12,5])
census.corr()['Income'].sort_values(ascending= False).drop('Income').plot(kind = 'bar', color ='green')
plt.xlabel('Column Names', fontsize = 12)
plt.ylabel('Correlation', fontsize = 12)
plt.title('Correlation with Target Column')
plt.show()
# Out:
# Education_num     0.335299
# Age               0.234039
# Hours_per_week    0.229659
# Capital_gain      0.223340
# Sex               0.215984
# Capital_loss      0.150498
# Education         0.079361
# Occupation        0.075398
# Race              0.071855
# Workclass         0.051706
# Native_country    0.015623
# Fnlwgt           -0.009521
# Marital_status   -0.199187
# Relationship     -0.250955
# Name: Income, dtype: float64

# %% [markdown]
# The column 'Education_num','Age','Hours_per_week' is having highest positve correlation with the target variable 'Income'.
# The columm 'Fnlwgt', 'Marital_status'and 'Relationship' is having highest negative correlation with the target variable 'Income' while rest others are in correlation with target variable .
# The column 'Workclass' is having least positve correlation to the target variable 'Income'. The column 'Fnlwgt' is having least negative correlation to the target variable 'Income'.

# %%
plt.figure(figsize=(18,10))
plot=1
for col in census:
    if plot<=15:
        plt.subplot(3,5,plot)
        sns.distplot(census[col],color='green', rug=True)
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %% [markdown]
# Almost all the data is skewed .Non of the data is normally distributed.
# Age and Fnlwgt are right skewed.
# Education_num,Education,marital status,Occupation,Relationship has variation, which need to be treated.
# captital_gain & Capital_loss are highly right skewed with majority values are zero.
# Although Hours_per_week seems Normal Distributed but it shows some variation in so, we need to treat.

# %%
#checking the skewness
census.skew().sort_values(ascending = False)
# Out:
# Capital_gain      11.949245
# Capital_loss       4.592622
# Fnlwgt             1.447695
# Income             1.211640
# Relationship       0.786514
# Age                0.557657
# Hours_per_week     0.228752
# Occupation         0.114542
# Marital_status    -0.012692
# Education_num     -0.309454
# Sex               -0.719400
# Workclass         -0.751854
# Education         -0.934180
# Race              -2.435283
# Native_country    -3.661060
# dtype: float64

# %% [markdown]
# - The columns 'Capital_gain', 'Capital_loss', 'Fnlwgt', 'Income' are having high positive skewness. The columns 'Native_country', 'Race' are having high negative skewness. we can ignore the column 'Income' as it is our target column

# %%
### STEP-2 Removing skewness 

#Removing skewness from the data with standard limit as +/-0.5. -
census.skew().sort_values(ascending=False)[np.abs(census.skew())>0.5]
# Out:
# Capital_gain      11.949245
# Capital_loss       4.592622
# Fnlwgt             1.447695
# Income             1.211640
# Relationship       0.786514
# Age                0.557657
# Sex               -0.719400
# Workclass         -0.751854
# Education         -0.934180
# Race              -2.435283
# Native_country    -3.661060
# dtype: float64

# %%
# Importing library to remove skewness .
from sklearn.preprocessing import power_transform
def skew(col):
    census[col]=power_transform((census[col].values.reshape(-1,1)))
    
skewed_col = ['Capital_gain','Capital_loss','Fnlwgt','Relationship','Education','Race','Native_country']
for col in skewed_col:
    skew(col)

# %%
census.skew()
# Out:
# Age               0.557657
# Workclass        -0.751854
# Fnlwgt            0.016961
# Education        -0.309379
# Education_num    -0.309454
# Marital_status   -0.012692
# Occupation        0.114542
# Relationship      0.123000
# Race             -2.010646
# Sex              -0.719400
# Capital_gain      3.015495
# Capital_loss      4.297677
# Hours_per_week    0.228752
# Native_country   -2.728041
# Income            1.211640
# dtype: float64

# %%
census.drop(['Capital_loss','Capital_gain'],axis = 1, inplace = True)
census.skew().sort_values(ascending = False)
# Out:
# Income            1.211640
# Age               0.557657
# Hours_per_week    0.228752
# Relationship      0.123000
# Occupation        0.114542
# Fnlwgt            0.016961
# Marital_status   -0.012692
# Education        -0.309379
# Education_num    -0.309454
# Sex              -0.719400
# Workclass        -0.751854
# Race             -2.010646
# Native_country   -2.728041
# dtype: float64

# %%
#detecting outliers
census.plot(kind='box',subplots=True,layout=(6,6),figsize=(18,15))
# Out:
# Age                   AxesSubplot(0.125,0.77;0.110714x0.11)
# Workclass          AxesSubplot(0.257857,0.77;0.110714x0.11)
# Fnlwgt             AxesSubplot(0.390714,0.77;0.110714x0.11)
# Education          AxesSubplot(0.523571,0.77;0.110714x0.11)
# Education_num      AxesSubplot(0.656429,0.77;0.110714x0.11)
# Marital_status     AxesSubplot(0.789286,0.77;0.110714x0.11)
# Occupation           AxesSubplot(0.125,0.638;0.110714x0.11)
# Relationship      AxesSubplot(0.257857,0.638;0.110714x0.11)
# Race              AxesSubplot(0.390714,0.638;0.110714x0.11)
# Sex               AxesSubplot(0.523571,0.638;0.110714x0.11)
# Capital_gain      AxesSubplot(0.656429,0.638;0.110714x0.11)
# Capital_loss      AxesSubplot(0.789286,0.638;0.110714x0.11)
# Hours_per_week       AxesSubplot(0.125,0.506;0.110714x0.11)
# Native_country    AxesSubplot(0.257857,0.506;0.110714x0.11)
# Income            AxesSubplot(0.390714,0.506;0.110714x0.11)
# dtype: object

# %% [markdown]
# outliers are present in all columns except the columns 'Marital_status', 'Occupation', 'Relationship', 'Sex'.
# The categorical columns 'Work class', 'Education', 'Race', 'Native_country','Income' can be ignored.

# %%
from scipy.stats import zscore
z = np.abs(zscore(census))
threshold = 3
df= census[(z<3).all(axis=1)]

# %%
df.shape
# Out:
# (29766, 13)

# %%
census.shape
# Out:
# (32536, 13)

# %%
data_loss = (census.shape[0]-df.shape[0])/census.shape[0]*100
data_loss
# Out:
# 8.51364642242439

# %%
df
# Out:
#        Age  Workclass    Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6 -1.089960  -0.476830             13               2
# 1       38          4  0.398771   0.090708              9               0
# 2       53          4  0.562562  -2.067623              7               2
# 4       37          4  0.957178   0.395380             14               2
# 6       52          6  0.345485   0.090708              9               2
# ...    ...        ...       ...        ...            ...             ...
# 32555   27          4  0.746761  -0.984585             12               2
# 32556   40          4 -0.193274   0.090708              9               2
# 32557   58          4 -0.219732   0.090708              9               6
# 32558   22          4  0.271699   0.090708              9               4
# 32559   52          5  0.982158   0.090708              9               2
#
#        Occupation  Relationship      Race  Sex  Hours_per_week  \
# 0               4     -1.094450  0.412918    1              13
# 1               6      0.134548  0.412918    1              40
# 2               6     -1.094450 -2.431782    1              40
# 4               4      1.548769  0.412918    0              40
# 6               4     -1.094450  0.412918    1              45
# ...           ...           ...       ...  ...             ...
# 32555          13      1.548769  0.412918    0              38
# 32556           7     -1.094450  0.412918    1              40
# 32557           1      1.351188  0.412918    0              40
# 32558           1      1.090940  0.412918    1              20
# 32559           4      1.548769  0.412918    0              40
#
#        Native_country  Income
# 0            0.328812       0
# 1            0.328812       0
# 2            0.328812       0
# 4            0.328812       0
# 6            0.328812       1
# ...               ...     ...
# 32555        0.328812       0
# 32556        0.328812       1
# 32557        0.328812       0
# 32558        0.328812       0
# 32559        0.328812       1
#
# [29766 rows x 13 columns]

# %%
x = df.drop('Income',axis = 1)
y = df['Income']
z = x.columns
print(x.shape)
print(y.shape)
# Out:
# (29766, 12)
# (29766,)

# %%
#Scaling the data using standardscaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x = sc.fit_transform(x)
x = pd.DataFrame(x,columns = z)
x
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.877253   1.468802 -1.090104  -0.497091       1.181554
# 1     -0.020764   0.092368  0.425291   0.073631      -0.462813
# 2      1.101757   0.092368  0.592016  -2.096810      -1.284997
# 3     -0.095599   0.092368  0.993699   0.380013       1.592646
# 4      1.026922   1.468802  0.371051   0.073631      -0.462813
# ...         ...        ...       ...        ...            ...
# 29761 -0.843946   0.092368  0.779514  -1.007695       0.770462
# 29762  0.128906   0.092368 -0.177357   0.073631      -0.462813
# 29763  1.475931   0.092368 -0.204290   0.073631      -0.462813
# 29764 -1.218120   0.092368  0.295943   0.073631      -0.462813
# 29765  1.026922   0.780585  1.019127   0.073631      -0.462813
#
#        Marital_status  Occupation  Relationship      Race       Sex  \
# 0           -0.398771   -0.603010     -1.097533  0.390825  0.706786
# 1           -1.723526   -0.132218      0.130259  0.390825  0.706786
# 2           -0.398771   -0.132218     -1.097533 -2.567339  0.706786
# 3           -0.398771   -0.603010      1.543093  0.390825 -1.414855
# 4           -0.398771   -0.603010     -1.097533  0.390825  0.706786
# ...               ...         ...           ...       ...       ...
# 29761       -0.398771    1.515556      1.543093  0.390825 -1.414855
# 29762       -0.398771    0.103179     -1.097533  0.390825  0.706786
# 29763        2.250740   -1.309198      1.345705  0.390825 -1.414855
# 29764        0.925985   -1.309198      1.085713  0.390825  0.706786
# 29765       -0.398771   -0.603010      1.543093  0.390825 -1.414855
#
#        Hours_per_week  Native_country
# 0           -2.423681        0.194453
# 1           -0.006353        0.194453
# 2           -0.006353        0.194453
# 3           -0.006353        0.194453
# 4            0.441301        0.194453
# ...               ...             ...
# 29761       -0.185414        0.194453
# 29762       -0.006353        0.194453
# 29763       -0.006353        0.194453
# 29764       -1.796966        0.194453
# 29765       -0.006353        0.194453
#
# [29766 rows x 12 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def vif(x):
    vif = pd.DataFrame()
    vif['Column Name'] = x.columns
    vif['VIF Factor'] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif)
vif(x)
# Out:
#        Column Name  VIF Factor
# 0              Age    1.215192
# 1        Workclass    1.087048
# 2           Fnlwgt    1.018101
# 3        Education    1.094454
# 4    Education_num    1.157457
# 5   Marital_status    1.162312
# 6       Occupation    1.086488
# 7     Relationship    1.928741
# 8             Race    1.041171
# 9              Sex    1.644473
# 10  Hours_per_week    1.155102
# 11  Native_country    1.044465

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from xgboost import XGBClassifier

from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,plot_roc_curve,roc_curve,roc_auc_score

# %%
def random_st_cls(model):
    max_score = 0
    max_rs = 0
    print('\n',model)
    for i in range(1,50):
        x_train, x_test,y_train,y_test= train_test_split(x,y,test_size = 0.30, random_state = i)
        model.fit(x_train,y_train)
        pred_test = model.predict(x_test)
        score = accuracy_score(y_test,pred_test)
        if score > max_score:
            max_score = score
            max_rs = i
    print("At random state ", max_rs, 'the model is having accuracy score of ', max_score)
    return max_rs

# %%
def model_fit_cls(model, rs):
    x_train, x_test,y_train,y_test= train_test_split(x,y,test_size = 0.30, random_state = rs)
    model.fit(x_train,y_train)
    pred_test = model.predict(x_test)
    cv_score = cross_val_score(model,x,y, cv = 5)
    cv_mean = cv_score.mean()
    print(f" Accuracy score is: {accuracy_score(y_test,pred_test)*100:.2f}")
    print ('\n','Confusion matrix:','\n',confusion_matrix(y_test,pred_test))
    print ('\n','Classification Report:','\n',classification_report(y_test,pred_test))
    print("The cv score is ", cv_mean, "and the accuracy score  is ",accuracy_score(y_test,pred_test))
    print(f'\n Difference between accuracy score and cross val score {(accuracy_score(y_test,pred_test)-cv_mean)*100:.2f}')
    print("-"*50)

# %%
def model_cls(m):
    m_rs = random_st_cls(m)
    model_fit_cls(m,m_rs)

# %%
Model_classify = [LogisticRegression(),RandomForestClassifier(), KNeighborsClassifier(),DecisionTreeClassifier(),GradientBoostingClassifier(),AdaBoostClassifier(),SVC(),ExtraTreesClassifier(),XGBClassifier()]

# %%
for i in Model_classify:
    model_cls(i)
# Out:
#  LogisticRegression()
# At random state  49 the model is having accuracy score of  0.8215005599104144
#  Accuracy score is: 82.15
#
#  Confusion matrix:
#  [[6383  426]
#  [1168  953]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89      6809
#            1       0.69      0.45      0.54      2121
#
#     accuracy                           0.82      8930
#    macro avg       0.77      0.69      0.72      8930
# weighted avg       0.81      0.82      0.81      8930
#
# The cv score is  0.8130419221083575 and the accuracy score  is  0.8215005599104144
#
#  Difference between accuracy score and cross val score 0.85
# --------------------------------------------------
#
#  RandomForestClassifier()
# At random state  42 the model is having accuracy score of  0.832922732362822
#  Accuracy score is: 83.36
#
#  Confusion matrix:
#  [[6241  599]
#  [ 887 1203]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89      6840
#            1       0.67      0.58      0.62      2090
#
#     accuracy                           0.83      8930
#    macro avg       0.77      0.74      0.76      8930
# weighted avg       0.83      0.83      0.83      8930
#
# The cv score is  0.8258750933369507 and the accuracy score  is  0.8335946248600224
#
#  Difference between accuracy score and cross val score 0.77
# --------------------------------------------------
#
#  KNeighborsClassifier()
# At random state  28 the model is having accuracy score of  0.8230683090705487
#  Accuracy score is: 82.31
#
#  Confusion matrix:
#  [[6112  690]
#  [ 890 1238]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89      6802
#            1       0.64      0.58      0.61      2128
#
#     accuracy                           0.82      8930
#    macro avg       0.76      0.74      0.75      8930
# weighted avg       0.82      0.82      0.82      8930
#
# The cv score is  0.8145870961767978 and the accuracy score  is  0.8230683090705487
#
#  Difference between accuracy score and cross val score 0.85
# --------------------------------------------------
#
#  DecisionTreeClassifier()
# At random state  11 the model is having accuracy score of  0.7820828667413214
#  Accuracy score is: 78.13
#
#  Confusion matrix:
#  [[5770 1027]
#  [ 926 1207]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86      6797
#            1       0.54      0.57      0.55      2133
#
#     accuracy                           0.78      8930
#    macro avg       0.70      0.71      0.70      8930
# weighted avg       0.78      0.78      0.78      8930
#
# The cv score is  0.775818201034066 and the accuracy score  is  0.7812989921612542
#
#  Difference between accuracy score and cross val score 0.55
# --------------------------------------------------
#
#  GradientBoostingClassifier()
# At random state  49 the model is having accuracy score of  0.8474804031354983
#  Accuracy score is: 84.75
#
#  Confusion matrix:
#  [[6344  465]
#  [ 897 1224]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      6809
#            1       0.72      0.58      0.64      2121
#
#     accuracy                           0.85      8930
#    macro avg       0.80      0.75      0.77      8930
# weighted avg       0.84      0.85      0.84      8930
#
# The cv score is  0.8421018502285369 and the accuracy score  is  0.8474804031354983
#
#  Difference between accuracy score and cross val score 0.54
# --------------------------------------------------
#
#  AdaBoostClassifier()
# At random state  41 the model is having accuracy score of  0.8423292273236282
#  Accuracy score is: 84.23
#
#  Confusion matrix:
#  [[6253  471]
#  [ 937 1269]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90      6724
#            1       0.73      0.58      0.64      2206
#
#     accuracy                           0.84      8930
#    macro avg       0.80      0.75      0.77      8930
# weighted avg       0.84      0.84      0.84      8930
#
# The cv score is  0.8374656678298671 and the accuracy score  is  0.8423292273236282
#
#  Difference between accuracy score and cross val score 0.49
# --------------------------------------------------
#
#  SVC()
# At random state  32 the model is having accuracy score of  0.832922732362822
#  Accuracy score is: 83.29
#
#  Confusion matrix:
#  [[6414  411]
#  [1081 1024]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      6825
#            1       0.71      0.49      0.58      2105
#
#     accuracy                           0.83      8930
#    macro avg       0.78      0.71      0.74      8930
# weighted avg       0.82      0.83      0.82      8930
#
# The cv score is  0.8265472943047716 and the accuracy score  is  0.832922732362822
#
#  Difference between accuracy score and cross val score 0.64
# --------------------------------------------------
#
#  ExtraTreesClassifier()
# At random state  28 the model is having accuracy score of  0.8257558790593506
#  Accuracy score is: 82.55
#
#  Confusion matrix:
#  [[6129  673]
#  [ 885 1243]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89      6802
#            1       0.65      0.58      0.61      2128
#
#     accuracy                           0.83      8930
#    macro avg       0.76      0.74      0.75      8930
# weighted avg       0.82      0.83      0.82      8930
#
# The cv score is  0.8194584315464983 and the accuracy score  is  0.825531914893617
#
#  Difference between accuracy score and cross val score 0.61
# --------------------------------------------------
#
#  XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
# At random state  49 the model is having accuracy score of  0.8425531914893617
#  Accuracy score is: 84.26
#
#  Confusion matrix:
#  [[6246  563]
#  [ 843 1278]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90      6809
#            1       0.69      0.60      0.65      2121
#
#     accuracy                           0.84      8930
#    macro avg       0.79      0.76      0.77      8930
# weighted avg       0.84      0.84      0.84      8930
#
# The cv score is  0.8361217060231245 and the accuracy score  is  0.8425531914893617
#
#  Difference between accuracy score and cross val score 0.64
# --------------------------------------------------

# %% [markdown]
# Hyper Parameter tuning

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=41)

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'n_estimators':[100,500,1000],
              'algorithm':['SAMME', 'SAMME.R'],
              'learning_rate':[.001,0.01,.1],
              'base_estimator': [DecisionTreeClassifier(max_depth=1), DecisionTreeClassifier(max_depth=2)]}
grid = GridSearchCV(estimator = AdaBoostClassifier(),param_grid=parameters, cv = 5)

# %%
grid.fit(x,y)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'base_estimator': [DecisionTreeClassifier(max_depth=1),
#                                             DecisionTreeClassifier(max_depth=2)],
#                          'learning_rate': [0.001, 0.01, 0.1],
#                          'n_estimators': [100, 500, 1000]})

# %%
grid.best_score_
# Out:
# 0.8413626763132388

# %%
grid.best_params_
# Out:
# {'algorithm': 'SAMME.R',
#  'base_estimator': DecisionTreeClassifier(max_depth=2),
#  'learning_rate': 0.1,
#  'n_estimators': 500}

# %%
final_model_cls = AdaBoostClassifier(algorithm= 'SAMME.R',base_estimator= DecisionTreeClassifier(max_depth=2),learning_rate= 0.1,n_estimators=500)
final_model_cls.fit(x_train,y_train)
y_pred=final_model_cls.predict(x_test)
print('classification report',classification_report(y_test,y_pred))
print('confusion_matrix:',confusion_matrix(y_test,y_pred))
print('\n Accuracy of Classifier After Hyperparameter Tuning',accuracy_score(y_test,y_pred)*100)
# Out:
# classification report               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      6724
#            1       0.74      0.60      0.66      2206
#
#     accuracy                           0.85      8930
#    macro avg       0.81      0.76      0.78      8930
# weighted avg       0.84      0.85      0.84      8930
#
# confusion_matrix: [[6251  473]
#  [ 891 1315]]
#
#  Accuracy of Classifier After Hyperparameter Tuning 84.7256438969765

# %%
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(data=cm,linewidths=.5,annot=True)
plt.xlabel('Actual label')
plt.ylabel('Predicted label')
all_sample_title='Accuracy for AdaBoostClassifier :{0}'.format(final_model_cls.score(x_test,y_test))
plt.title(all_sample_title)
# Out:
# Text(0.5, 1.0, 'Accuracy for AdaBoostClassifier :0.8472564389697649')

# %%
def auc_roc(model):
    y_pred_prob = model.predict_proba(x_test)[:,1]
    fpr,tpr,thresholds = roc_curve(y_test,y_pred_prob)
    auc_score = roc_auc_score(y_test, model.predict(x_test))
    plt.plot([0,1],[0,1],'k--')
    plt.plot(fpr, tpr, label = 'AUC ='+str(round(auc_score,2)))
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc = 'lower right')
    plt.title(model)
    plt.show()
auc_roc(final_model_cls)

# %%
import pickle
filename = 'census_classification.pkl'
pickle.dump(final_model_cls,open(filename,'wb'))

# %%
original = np.array(y_test)
predicted = np.round(np.array(final_model_cls.predict(x_test)),0)

income_prediction = pd.DataFrame({'Original':original,'Predicted Income Status':predicted}).T
income_prediction
# Out:
#                          0     1     2     3     4     5     6     7     8     \
# Original                    0     0     0     0     0     0     0     0     0
# Predicted Income Status     0     0     0     1     0     0     1     0     0
#
#                          9     ...  8920  8921  8922  8923  8924  8925  8926  \
# Original                    0  ...     0     1     0     1     0     0     0
# Predicted Income Status     0  ...     0     1     0     0     1     0     0
#
#                          8927  8928  8929
# Original                    0     0     0
# Predicted Income Status     0     0     1
#
# [2 rows x 8930 columns]
